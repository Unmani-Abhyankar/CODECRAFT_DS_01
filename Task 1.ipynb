# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Using the provided dataset

# %%
## importing the datatset

df = pd.read_csv(r"D:\\API_SP.POP.TOTL_DS2_en_csv_v2_3515.csv",skiprows=4)

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df_2024 = df[["Country Name","2024"]].dropna()

# %%
# Sorting the countries by 2024 population in descending order

df_sorted = df_2024.sort_values(by='2024', ascending=False)

# %%
top_10_country = df_sorted.head(10)
top_10_country
# Out:
#                    Country Name          2024
# 259                       World  8.142056e+09
# 103            IDA & IBRD total  6.926456e+09
# 140         Low & middle income  6.563720e+09
# 156               Middle income  5.939112e+09
# 102                   IBRD only  4.979720e+09
# 62   Early-demographic dividend  3.552279e+09
# 139         Lower middle income  3.120984e+09
# 249         Upper middle income  2.818128e+09
# 63          East Asia & Pacific  2.388378e+09
# 142   Late-demographic dividend  2.328891e+09

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_country, x='2024', y='Country Name')

plt.title('Top 10 Most Populous Countries (2024)', fontsize=14)
plt.xlabel('Population', fontsize=12)
plt.ylabel('Country', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %%
##  Histogram – Population Distribution -

plt.hist(df_2024['2024'], bins=20, color='purple', edgecolor='green')

plt.title('Population Distribution Across Countries (2024)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.tight_layout()
plt.show()

# %%
# Line Plot:-

# Population trend of India from 1960 to 2022

india = df[df['Country Name'] == 'India'].iloc[0, 4:-1] 
years = india.index.astype(str)
population = india.values.astype(float)

plt.figure(figsize=(10, 5))
plt.plot(years, population, marker='o', color='green')
plt.xticks(rotation=65)
plt.title('Population Growth of India (1960–2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Stacked Area Plot for 3 Countries (1960–2022) -

# Reloading full data with years
df_years = df[df['Country Name'].isin(['India', 'China', 'United States'])]

# Extracting year columns
df_plot = df_years.set_index('Country Name').loc[:, '1960':'2022'].transpose()
df_plot = df_plot.astype(float)

plt.figure(figsize=(12, 6))
df_plot.plot.area()
plt.title('Population Growth of India, China & USA (1960–2022)')
plt.ylabel('Population')
plt.xlabel('Year')
plt.tight_layout()
plt.show()
